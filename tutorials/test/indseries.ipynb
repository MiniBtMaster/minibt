# %%
from minibt import *
kline=LocalDatas.v2601_300.kline
kline.head()

# %%
sma=kline.close.sma()
sma,type(sma)

# %%
sma.btplot('last')

# %%
(sma.line_style
,sma.line_dash
,sma.line_width
,sma.line_color)

# %%
sma.line_style=LineStyle()
sma.line_dash=LineDash.dashdot
sma.line_width=3.
sma.line_color=Colors.blue

# %%
sma.btplot('last')
