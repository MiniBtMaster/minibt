# %%
from minibt import *

# %%
series = IndSeries()

# %%
series[:]=range(10)
series,type(series)

# %%
print(series.kline,series.source_object)

# %%
series.btplot()

# %%
series.iloc[9]=100
series

# %%
series[:]=range(100)
series

# %%
series.lines=["series"]
series.get_indicator_kwargs()
